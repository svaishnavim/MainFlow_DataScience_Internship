# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(r"C:\Users\myacc\OneDrive\Documents\INTERNSHIP_TASKS\dataset_task2.csv")

# %%
df.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
#shape of the original dataset
df.shape
# Out:
# (324, 23)

# %% [markdown]
# ## About Dataset

# %%
df.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
#check for null items
df.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %% [markdown]
# ## Handling missing data

# %%
#fill missing values using medians
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].median())

# %% [markdown]
# ## Filter data
# Filter based on a condition

# %%
filtered_df = df[df['ChipRate'] > 16.5]

# %%
filtered_df.head()
# Out:
#    Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0     31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1     31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2     31-02:00    23.19    16.709      79.562  1329.407      239.161
# 14    31-13:00    24.05    16.675      77.025  1284.386      246.336
# 57     2-08:00    22.53    16.783      76.396  1281.536      269.496
#
#     T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0         358.282         329.545  1.443       599.253  ...        67.122
# 1         351.050         329.067  1.549       537.201  ...        60.012
# 2         350.022         329.260  1.600       549.611  ...        61.304
# 14        350.317         329.240  1.538       537.811  ...        58.979
# 57        351.640         324.093  1.556       622.751  ...        67.107
#
#     Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
#shape of the filtered df
filtered_df.shape
# Out:
# (22, 23)

# %%
#check for null values
filtered_df.isnull().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        0
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      0
# dtype: int64

# %%
#describe data
filtered_df.describe()
# Out:
#          Y-Kappa   ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  22.000000  22.000000   22.000000    22.000000    22.000000
# mean   22.693182  16.711545   82.495045  1265.070227   264.940273
# std     2.762220   0.120886   13.230384    43.552017    57.317157
# min    17.800000  16.518000   73.381000  1177.607000   169.805000
# 25%    21.757500  16.637500   76.862750  1237.144250   211.848250
# 50%    23.195000  16.704500   78.446000  1276.082000   268.365500
# 75%    23.962500  16.810000   79.562000  1284.733250   301.837750
# max    27.600000  16.958000  121.717000  1329.407000   344.674000
#
#        T-upperExt-2   T-lowerExt-2        UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count      22.000000       22.000000  22.000000     22.000000     22.000000
# mean      355.318364      327.306773   1.523000    602.821455      6.143818
# std         4.670062        2.388754   0.065525     52.085433      0.037041
# ...

# %% [markdown]
# ## PLOTS OF THE DATASET

# %% [markdown]
# ### plot 1 - line plot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.plot(filtered_df['Observation'], filtered_df['ChipRate'])
plt.title('ChipRate Over Time')
plt.xlabel('Observation')
plt.ylabel('ChipRate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
